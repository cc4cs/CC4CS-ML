# %%
# Declarations
import glob
import json
import os
import numpy as np
import pandas as pd
import re

from os.path import basename

# %%
dfRDC = pd.read_csv("RangeValueClassification_tot.csv", sep=';')
del dfRDC['Unnamed: 0']

# %%
dfRDC = pd.read_csv("RangeValueClassification_tot.csv", sep=';')
del dfRDC['Unnamed: 0']

# %%
nameFileH = []
pathFileH = []
rootFileH = []
nameFileM = []
pathFileM = []
rootFileM = []
nameFileS = []
pathFileS = []
rootFileS = []
nameFileC = []
pathFileC = []
rootFileC = []
nameFileA = []
pathFileA = []
rootFileA = []

path = os.getcwd()
for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith("Halsted.csv"):
            nameFileH.append(file)
            pathFileH.append(os.path.join(root, file))
            rootFileH.append(root)
        elif file.endswith("McCabe.csv"):
            nameFileM.append(file)
            pathFileM.append(os.path.join(root, file))
            rootFileM.append(root)
        elif file.endswith("cStatements.csv"):
            nameFileS.append(file)
            pathFileS.append(os.path.join(root, file))
            rootFileS.append(root)
        elif file.endswith("clockCycles.csv"):
            nameFileC.append(file)
            pathFileC.append(os.path.join(root, file))
            rootFileC.append(root)
        elif file.endswith("cc4csValues.csv"):
            nameFileA.append(file)
            pathFileA.append(os.path.join(root, file))
            rootFileA.append(root)
            
#indR = nameFileC.index("ParMatrixclockCycles.csv")
#nameFileC.remove("ParMatrixclockCycles.csv")
#del pathFileC[indR]
#del rootFileC[indR]

# %%
# Halsted file
for i in range(0, len(pathFileH)):
    path = pathFileH[i]
    try:
        dfHTemp = pd.read_csv(path, sep=',',engine='python')
    except:
        print(path)
        
    if os.name == 'nt':
        spR = rootFileH[i].split('\\')
    else:
        spR = rootFileH[i].split('/')
    datatype = spR[-1]
    device = spR[-5]
    board = spR[-4]
    function = spR[-2]
    dfHTemp['DEVICE'] = device
    dfHTemp['BOARD'] = board
    dfHTemp['FUNCTION'] = function
    dfHTemp['DATA_TYPE'] = datatype
    dfHTemp['inputName'] = dfHTemp['inputName'].map(lambda x: x.lstrip('values_'))
    dfHTemp['inputName'] = dfHTemp['inputName'].astype(int)
    dfHTemp.sort_values('inputName')
    
    if i == 0:
        dfHTot = dfHTemp
    else:
        frames = [dfHTot, dfHTemp]
        dfHTot = pd.concat(frames)
        
a = dfHTot['ProgramVolume']/3000
a = a.values.tolist()
dfHTot['BugsDelivered'] = a

# %%
# McCabe file
for i in range(0, len(pathFileM)):
    path = pathFileM[i]
    dfMTemp = pd.read_csv(path, sep=',',engine='python')

    if os.name == 'nt':
        spR = rootFileM[i].split('\\')
    else:
        spR = rootFileM[i].split('/')
    datatype = spR[-1]
    device = spR[-5]
    board = spR[-4]
    function = spR[-2]
    dfMTemp['DEVICE'] = device
    dfMTemp['BOARD'] = board
    dfMTemp['FUNCTION'] = function
    dfMTemp['DATA_TYPE'] = datatype
    dfMTemp['inputName'] = dfMTemp['inputName'].map(lambda x: x.lstrip('values_'))
    dfMTemp['inputName'] = dfMTemp['inputName'].astype(int)
    dfMTemp.sort_values('inputName')
    
    if i == 0:
        dfMTot = dfMTemp
    else:
        frames = [dfMTot, dfMTemp]
        dfMTot = pd.concat(frames)

# %%
# cStatement file
for i in range(0, len(pathFileS)):
    path = pathFileS[i]
    dfSTemp = pd.read_csv(path, sep=',',engine='python')
    
    if os.name == 'nt':
        spR = rootFileS[i].split('\\')
    else:
        spR = rootFileS[i].split('/')
    datatype = spR[-1]
    device = spR[-5]
    board = spR[-4]
    function = spR[-2]
    dfSTemp['DEVICE'] = device
    dfSTemp['BOARD'] = board
    dfSTemp['FUNCTION'] = function
    dfSTemp['DATA_TYPE'] = datatype
    dfSTemp['id'] = dfSTemp['id'].map(lambda x: x.lstrip('values_'))
    dfSTemp['id'] = dfSTemp['id'].astype(int)
    dfSTemp.sort_values('id')
    
    if i == 0:
        dfSTot = dfSTemp
    else:
        frames = [dfSTot, dfSTemp]
        dfSTot = pd.concat(frames)

# %%
# clockCycle file
for i in range(0, len(pathFileC)):
    path = pathFileC[i]
    dfCTemp = pd.read_csv(path, sep=',',engine='python')
    
    if os.name == 'nt':
        spR = rootFileC[i].split('\\')
    else:
        spR = rootFileC[i].split('/')
    datatype = spR[-1]
    device = spR[-5]
    board = spR[-4]
    function = spR[-2]
    dfCTemp['DEVICE'] = device
    dfCTemp['BOARD'] = board
    dfCTemp['FUNCTION'] = function
    dfCTemp['DATA_TYPE'] = datatype
    dfCTemp['id'] = dfCTemp['id'].map(lambda x: x.lstrip('values_'))
    dfCTemp['id'] = dfCTemp['id'].astype(int)
    dfCTemp.sort_values('id')
    
    if i == 0:
        dfCTot = dfCTemp
    else:
        frames = [dfCTot, dfCTemp]
        dfCTot = pd.concat(frames)

# %%
dfHTot = dfHTot.reset_index(drop=True)
dfMTot = dfMTot.reset_index(drop=True)
dfSTot = dfSTot.reset_index(drop=True)
dfCTot = dfCTot.reset_index(drop=True)

# %%
columnsH = ['DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE', 'BugsDelivered', 
            'DifficultyLevel', 'DistinctOperands', 
            'DistinctOperators', 'Effort', 'ProgramLength', 'ProgramLevel', 'ProgramVolume', 
            'TimeToImplement', 
            'TotalOperators', 'Total_Operands', 'VocabularySize']
columnsM = ['DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE', 'Sloc', 'DecisionPoint', 'GlobalVariables', 
            'If', 'Loop', 'Goto', 'Assignment', 'ExitPoint', 'Function', 'FunctionCall', 
            'PointerDereferencing', 'CyclomaticComplexity', 'SyntacticallyReachableFunctions', 
            'SemanticallyReachedFunctions', 'CoverageEstimation']
columnsS = ['DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE','cInstr']
columnsC = ['DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE','id','clockCycles', 'assemblyInstr']

# %%
dfPar1 = dfHTot.assign(**dfMTot)
dfPar2 = dfPar1.assign(**dfSTot)
dfPar3 = dfPar2.assign(**dfCTot)

# %%
dfTot = pd.merge(dfPar3,dfRDC,how='left',on=['DEVICE','BOARD','FUNCTION','DATA_TYPE'])
#dfTot = pd.merge(dfPar4,dfRDC,how='left',on=['DEVICE','BOARD','FUNCTION','DATA_TYPE','ID_VAL'])
columnsTot = ['DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE',
              'id','BugsDelivered', 'DifficultyLevel','DistinctOperands', 'DistinctOperators', 'Effort', 'ProgramLength',
              'ProgramLevel', 'ProgramVolume', 'TimeToImplement', 'TotalOperators',
              'Total_Operands', 'VocabularySize', 'Sloc', 'DecisionPoint','GlobalVariables', 
              'If', 'Loop', 'Goto', 'Assignment', 'ExitPoint',
              'Function', 'FunctionCall', 'PointerDereferencing','CyclomaticComplexity', 
              'SyntacticallyReachableFunctions','SemanticallyReachedFunctions', 'CoverageEstimation', 
              'NUM_S', 'RANGE_S', 'NUM_SI','RANGE_SI', 'NUM_ARR', 'RANGE_ARR',
              'cInstr', 'assemblyInstr',
              'clockCycles'] # E' UN OUTPUT
              #'DSP','BRAM','Flip_Flop','Area','min_Slack','Max_Freq',   # COLONNE PRESENTI SOLO CON BAMBU (HW) E SONOI OUPUT, CAMBIANO PER SW
              #, 'cc4cs'] # DA CALCOLARE
dfTot = dfTot[columnsTot]

# %%
dfTot['CC4CS'] = (dfTot['clockCycles'].astype('float64')).div(dfTot['cInstr'].astype('float64')).replace(np.inf,0)

# %%
dfTot.rename(columns={'id':'ID_VAL',
                      'NUM_S':'SCALAR_INPUT',
                      'RANGE_S':'RANGE_SCALAR_VALUES',
                      'NUM_SI':'SCALAR_INDEX_INPUT',
                      'RANGE_SI':'RANGE_SCALAR_INDEX_VALUES',
                      'NUM_ARR':'ARRAY_INPUT',
                      'RANGE_ARR':'RANGE_ARRAY_INPUT'}, inplace=True)

# %%
dfTot.to_csv("TotalParameterMatrix.csv", sep=';')

# %%
dfTot
# Out:
#           DEVICE  BOARD          FUNCTION DATA_TYPE  ID_VAL  BugsDelivered  \
# 0      armulator  Arm4t  banker_algorithm    int8_t     242            NaN
# 1      armulator  Arm4t  banker_algorithm    int8_t     505            NaN
# 2      armulator  Arm4t  banker_algorithm    int8_t    1006            NaN
# 3      armulator  Arm4t  banker_algorithm    int8_t     924            NaN
# 4      armulator  Arm4t  banker_algorithm    int8_t     862            NaN
# ...          ...    ...               ...       ...     ...            ...
# 63567       tsim  Leon3     selectionsort    int8_t     636       0.441050
# 63568       tsim  Leon3     selectionsort    int8_t     450       0.400517
# 63569       tsim  Leon3     selectionsort    int8_t     106       0.506107
# 63570       tsim  Leon3     selectionsort    int8_t     699       0.384807
# 63571       tsim  Leon3     selectionsort    int8_t     578       0.369420
#
#        DifficultyLevel  DistinctOperands  DistinctOperators    Effort  ...  \
# 0                  NaN               NaN                NaN       NaN  ...
# 1                  NaN               NaN                NaN       NaN  ...
# 2                  NaN               NaN                NaN       NaN  ...
# 3                  NaN               NaN                NaN       NaN  ...
# 4                  NaN               NaN                NaN       NaN  ...
# ...                ...               ...                ...       ...  ...
# 63567            30.81              27.0               26.0  40772.61  ...
# 63568            32.78              23.0               26.0  39389.87  ...
# 63569            26.72              36.0               26.0  40572.89  ...
# 63570            35.75              20.0               26.0  41270.67  ...
# 63571            38.28              18.0               26.0  42421.91  ...
#
#        SCALAR_INPUT  RANGE_SCALAR_VALUES  SCALAR_INDEX_INPUT  \
# 0               0.0                  0.0                 2.0
# 1               0.0                  0.0                 2.0
# 2               0.0                  0.0                 2.0
# 3               0.0                  0.0                 2.0
# 4               0.0                  0.0                 2.0
# ...             ...                  ...                 ...
# 63567           0.0                  0.0                 1.0
# 63568           0.0                  0.0                 1.0
# 63569           0.0                  0.0                 1.0
# 63570           0.0                  0.0                 1.0
# 63571           0.0                  0.0                 1.0
#
#        RANGE_SCALAR_INDEX_VALUES  ARRAY_INPUT  RANGE_ARRAY_INPUT  cInstr  \
# 0                            3.0          3.0                0.0     809
# 1                            3.0          3.0                0.0     101
# 2                            3.0          3.0                0.0     140
# 3                            3.0          3.0                0.0     117
# 4                            3.0          3.0                0.0     517
# ...                          ...          ...                ...     ...
# 63567                        3.0          1.0                1.0       9
# 63568                        3.0          1.0                1.0       9
# 63569                        3.0          1.0                1.0       9
# 63570                        3.0          1.0                1.0       9
# 63571                        3.0          1.0                1.0       9
#
#        assemblyInstr  clockCycles        CC4CS
# 0            24100.0      42896.0    53.023486
# 1             2351.0       4519.0    44.742574
# 2             3055.0       5895.0    42.107143
# 3             2103.0       4135.0    35.341880
# 4            16595.0      28591.0    55.301741
# ...              ...          ...          ...
# 63567         3962.0       8389.0   932.111111
# 63568         4851.0      10152.0  1128.000000
# 63569         1371.0       4136.0   459.555556
# 63570        12015.0      24180.0  2686.666667
# 63571         7638.0      15611.0  1734.555556
#
# [63572 rows x 42 columns]

# %%
dfBamb = dfTot.loc[(dfTot['DEVICE'] == 'thumbulator')]

# %%
dfBamb.head()
# Out:
#             DEVICE    BOARD          FUNCTION DATA_TYPE  ID_VAL  \
# 32836  thumbulator  Armv6-M  banker_algorithm    int8_t     242
# 32837  thumbulator  Armv6-M  banker_algorithm    int8_t     505
# 32838  thumbulator  Armv6-M  banker_algorithm    int8_t    1006
# 32839  thumbulator  Armv6-M  banker_algorithm    int8_t     924
# 32840  thumbulator  Armv6-M  banker_algorithm    int8_t     862
#
#        BugsDelivered  DifficultyLevel  DistinctOperands  DistinctOperators  \
# 32836            NaN              NaN               NaN                NaN
# 32837            NaN              NaN               NaN                NaN
# 32838            NaN              NaN               NaN                NaN
# 32839            NaN              NaN               NaN                NaN
# 32840            NaN              NaN               NaN                NaN
#
#        Effort  ...  SCALAR_INPUT  RANGE_SCALAR_VALUES  SCALAR_INDEX_INPUT  \
# 32836     NaN  ...           0.0                  0.0                 2.0
# 32837     NaN  ...           0.0                  0.0                 2.0
# 32838     NaN  ...           0.0                  0.0                 2.0
# 32839     NaN  ...           0.0                  0.0                 2.0
# 32840     NaN  ...           0.0                  0.0                 2.0
#
#        RANGE_SCALAR_INDEX_VALUES  ARRAY_INPUT  RANGE_ARRAY_INPUT  cInstr  \
# 32836                        3.0          3.0                0.0     809
# 32837                        3.0          3.0                0.0     101
# 32838                        3.0          3.0                0.0     140
# 32839                        3.0          3.0                0.0     117
# 32840                        3.0          3.0                0.0     517
#
#        assemblyInstr  clockCycles       CC4CS
# 32836       106031.0     142624.0  176.296663
# 32837        10285.0      14228.0  140.871287
# 32838        12690.0      17568.0  125.485714
# 32839         5600.0       7768.0   66.393162
# 32840        63115.0      86398.0  167.114120
#
# [5 rows x 42 columns]

# %%
dfBamb.columns
# Out:
# Index(['DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE', 'ID_VAL', 'BugsDelivered',
#        'DifficultyLevel', 'DistinctOperands', 'DistinctOperators', 'Effort',
#        'ProgramLength', 'ProgramLevel', 'ProgramVolume', 'TimeToImplement',
#        'TotalOperators', 'Total_Operands', 'VocabularySize', 'Sloc',
#        'DecisionPoint', 'GlobalVariables', 'If', 'Loop', 'Goto', 'Assignment',
#        'ExitPoint', 'Function', 'FunctionCall', 'PointerDereferencing',
#        'CyclomaticComplexity', 'SyntacticallyReachableFunctions',
#        'SemanticallyReachedFunctions', 'CoverageEstimation', 'SCALAR_INPUT',
#        'RANGE_SCALAR_VALUES', 'SCALAR_INDEX_INPUT',
#        'RANGE_SCALAR_INDEX_VALUES', 'ARRAY_INPUT', 'RANGE_ARRAY_INPUT',
#        'cInstr', 'assemblyInstr', 'clockCycles', 'CC4CS'],
#       dtype='object')

# %%
dfBamb.groupby(['DEVICE','BOARD','FUNCTION']).count()
# Out:
#                                       DATA_TYPE  ID_VAL  BugsDelivered  \
# DEVICE      BOARD   FUNCTION
# thumbulator Armv6-M banker_algorithm       1024    1024              0
#                     bellmanford            1000    1000           1000
#                     bfs                    1000    1000           1000
#                     binary_search          1024    1024           1024
#                     bubble_sort            1000    1000           1000
#                     fibcall                1000    1000           1000
#                     gcd                    1024    1024           1024
#                     insertionsort          1000    1000           1000
#                     kruskal                1000    1000           1000
#                     matrix_mult            1296    1296           1296
#                     mergesort              1000    1000           1000
#                     park_miller            1000    1000           1000
#                     qsort                  1000    1000           1000
#                     quicksort              1000    1000           1000
#                     selectionsort          1000    1000           1000
#
#                                       DifficultyLevel  DistinctOperands  \
# DEVICE      BOARD   FUNCTION
# thumbulator Armv6-M banker_algorithm                0                 0
#                     bellmanford                  1000              1000
#                     bfs                          1000              1000
#                     binary_search                1024              1024
#                     bubble_sort                  1000              1000
#                     fibcall                      1000              1000
#                     gcd                          1024              1024
#                     insertionsort                1000              1000
#                     kruskal                      1000              1000
#                     matrix_mult                  1296              1296
#                     mergesort                    1000              1000
#                     park_miller                  1000              1000
#                     qsort                        1000              1000
#                     quicksort                    1000              1000
#                     selectionsort                1000              1000
#
#                                       DistinctOperators  Effort  \
# DEVICE      BOARD   FUNCTION
# thumbulator Armv6-M banker_algorithm                  0       0
#                     bellmanford                    1000    1000
#                     bfs                            1000    1000
#                     binary_search                  1024    1024
#                     bubble_sort                    1000    1000
#                     fibcall                        1000    1000
#                     gcd                            1024    1024
#                     insertionsort                  1000    1000
#                     kruskal                        1000    1000
#                     matrix_mult                    1296    1296
#                     mergesort                      1000    1000
#                     park_miller                    1000    1000
#                     qsort                          1000    1000
#                     quicksort                      1000    1000
#                     selectionsort                  1000    1000
#
#                                       ProgramLength  ProgramLevel  \
# DEVICE      BOARD   FUNCTION
# thumbulator Armv6-M banker_algorithm              0             0
#                     bellmanford                1000          1000
#                     bfs                        1000          1000
#                     binary_search              1024          1024
#                     bubble_sort                1000          1000
#                     fibcall                    1000          1000
#                     gcd                        1024          1024
#                     insertionsort              1000          1000
#                     kruskal                    1000          1000
#                     matrix_mult                1296          1296
#                     mergesort                  1000          1000
#                     park_miller                1000          1000
#                     qsort                      1000          1000
#                     quicksort                  1000          1000
#                     selectionsort              1000          1000
#
#                                       ProgramVolume  ...  SCALAR_INPUT  \
# DEVICE      BOARD   FUNCTION                         ...
# thumbulator Armv6-M banker_algorithm              0  ...          1024
#                     bellmanford                1000  ...          1000
#                     bfs                        1000  ...             0
#                     binary_search              1024  ...          1024
#                     bubble_sort                1000  ...          1000
#                     fibcall                    1000  ...          1000
#                     gcd                        1024  ...          1024
#                     insertionsort              1000  ...          1000
#                     kruskal                    1000  ...          1000
#                     matrix_mult                1296  ...          1296
#                     mergesort                  1000  ...          1000
#                     park_miller                1000  ...          1000
#                     qsort                      1000  ...          1000
#                     quicksort                  1000  ...          1000
#                     selectionsort              1000  ...          1000
#
#                                       RANGE_SCALAR_VALUES  SCALAR_INDEX_INPUT  \
# DEVICE      BOARD   FUNCTION
# thumbulator Armv6-M banker_algorithm                 1024                1024
#                     bellmanford                      1000                1000
#                     bfs                                 0                   0
#                     binary_search                    1024                1024
#                     bubble_sort                      1000                1000
#                     fibcall                          1000                1000
#                     gcd                              1024                1024
#                     insertionsort                    1000                1000
#                     kruskal                          1000                1000
#                     matrix_mult                      1296                1296
#                     mergesort                        1000                1000
#                     park_miller                      1000                1000
#                     qsort                            1000                1000
#                     quicksort                        1000                1000
#                     selectionsort                    1000                1000
#
#                                       RANGE_SCALAR_INDEX_VALUES  ARRAY_INPUT  \
# DEVICE      BOARD   FUNCTION
# thumbulator Armv6-M banker_algorithm                       1024         1024
#                     bellmanford                            1000         1000
#                     bfs                                       0            0
#                     binary_search                          1024         1024
#                     bubble_sort                            1000         1000
#                     fibcall                                1000         1000
#                     gcd                                    1024         1024
#                     insertionsort                          1000         1000
#                     kruskal                                1000         1000
#                     matrix_mult                            1296         1296
#                     mergesort                              1000         1000
#                     park_miller                            1000         1000
#                     qsort                                  1000         1000
#                     quicksort                              1000         1000
#                     selectionsort                          1000         1000
#
#                                       RANGE_ARRAY_INPUT  cInstr  \
# DEVICE      BOARD   FUNCTION
# thumbulator Armv6-M banker_algorithm               1024    1024
#                     bellmanford                    1000    1000
#                     bfs                               0    1000
#                     binary_search                  1024    1024
#                     bubble_sort                    1000    1000
#                     fibcall                        1000    1000
#                     gcd                            1024    1024
#                     insertionsort                  1000    1000
#                     kruskal                        1000    1000
#                     matrix_mult                    1296    1296
#                     mergesort                      1000    1000
#                     park_miller                    1000    1000
#                     qsort                          1000    1000
#                     quicksort                      1000    1000
#                     selectionsort                  1000    1000
#
#                                       assemblyInstr  clockCycles  CC4CS
# DEVICE      BOARD   FUNCTION
# thumbulator Armv6-M banker_algorithm           1024         1024   1024
#                     bellmanford                1000         1000   1000
#                     bfs                        1000         1000   1000
#                     binary_search              1024         1024   1024
#                     bubble_sort                1000         1000   1000
#                     fibcall                    1000         1000   1000
#                     gcd                        1024         1024   1024
#                     insertionsort              1000         1000   1000
#                     kruskal                    1000         1000   1000
#                     matrix_mult                1296         1296   1296
#                     mergesort                  1000         1000   1000
#                     park_miller                1000         1000   1000
#                     qsort                      1000         1000   1000
#                     quicksort                  1000         1000   1000
#                     selectionsort              1000         1000   1000
#
# [15 rows x 39 columns]

# %%
dfATot.columns
# Out:
# Index(['DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE', 'ID_VAL', 'DSP', 'BRAM',
#        'Flip_Flop', 'Area', 'min_Slack', 'Max_Freq', 'Time', 'Energy'],
#       dtype='object')

# %%
dfBamb.loc[dfTot['FUNCTION'] == 'gcd'].groupby(['DEVICE','BOARD','FUNCTION','DATA_TYPE']).count()
# Out:
#                                         ID_VAL  BugsDelivered  \
# DEVICE      BOARD   FUNCTION DATA_TYPE
# thumbulator Armv6-M gcd      int8_t       1024           1024
#
#                                         DifficultyLevel  DistinctOperands  \
# DEVICE      BOARD   FUNCTION DATA_TYPE
# thumbulator Armv6-M gcd      int8_t                1024              1024
#
#                                         DistinctOperators  Effort  \
# DEVICE      BOARD   FUNCTION DATA_TYPE
# thumbulator Armv6-M gcd      int8_t                  1024    1024
#
#                                         ProgramLength  ProgramLevel  \
# DEVICE      BOARD   FUNCTION DATA_TYPE
# thumbulator Armv6-M gcd      int8_t              1024          1024
#
#                                         ProgramVolume  TimeToImplement  ...  \
# DEVICE      BOARD   FUNCTION DATA_TYPE                                  ...
# thumbulator Armv6-M gcd      int8_t              1024             1024  ...
#
#                                         SCALAR_INPUT  RANGE_SCALAR_VALUES  \
# DEVICE      BOARD   FUNCTION DATA_TYPE
# thumbulator Armv6-M gcd      int8_t             1024                 1024
#
#                                         SCALAR_INDEX_INPUT  \
# DEVICE      BOARD   FUNCTION DATA_TYPE
# thumbulator Armv6-M gcd      int8_t                   1024
#
#                                         RANGE_SCALAR_INDEX_VALUES  \
# DEVICE      BOARD   FUNCTION DATA_TYPE
# thumbulator Armv6-M gcd      int8_t                          1024
#
#                                         ARRAY_INPUT  RANGE_ARRAY_INPUT  \
# DEVICE      BOARD   FUNCTION DATA_TYPE
# thumbulator Armv6-M gcd      int8_t            1024               1024
#
#                                         cInstr  assemblyInstr  clockCycles  \
# DEVICE      BOARD   FUNCTION DATA_TYPE
# thumbulator Armv6-M gcd      int8_t       1024           1024         1024
#
#                                         CC4CS
# DEVICE      BOARD   FUNCTION DATA_TYPE
# thumbulator Armv6-M gcd      int8_t      1024
#
# [1 rows x 38 columns]

# %%
dfBamb.columns
# Out:
# Index(['DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE', 'ID_VAL', 'BugsDelivered',
#        'DifficultyLevel', 'DistinctOperands', 'DistinctOperators', 'Effort',
#        'ProgramLength', 'ProgramLevel', 'ProgramVolume', 'TimeToImplement',
#        'TotalOperators', 'Total_Operands', 'VocabularySize', 'Sloc',
#        'DecisionPoint', 'GlobalVariables', 'If', 'Loop', 'Goto', 'Assignment',
#        'ExitPoint', 'Function', 'FunctionCall', 'PointerDereferencing',
#        'CyclomaticComplexity', 'SyntacticallyReachableFunctions',
#        'SemanticallyReachedFunctions', 'CoverageEstimation', 'SCALAR_INPUT',
#        'RANGE_SCALAR_VALUES', 'SCALAR_INDEX_INPUT',
#        'RANGE_SCALAR_INDEX_VALUES', 'ARRAY_INPUT', 'RANGE_ARRAY_INPUT',
#        'cInstr', 'assemblyInstr', 'clockCycles', 'CC4CS'],
#       dtype='object')

# %%
dfBamb.shape
# Out:
# (15368, 42)

# %%
dfTotPar['Bugs_Delivered'] = dfTotPar['ProgramVolume']/3000
dfTotPar['CC4CS'] = (dfTotPar['clockCycles'].astype('float64')).div(dfTotPar['cInstr'].astype('float64')).replace(np.inf,0)

# %%
dfBamb.to_csv("TotalParameterMatrixBambu.csv", sep=';')
